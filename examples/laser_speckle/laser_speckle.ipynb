# %%
# Useful for debugging
# %load_ext autoreload
# %autoreload 2
# %config InlineBackend.figure_format = 'retina'

# %%
from distgen import Generator
from matplotlib import pyplot as plt

# %%
from distgen.dist import UniformLaserSpeckle

# %%
params = {'min_x': '-1 mm', 'max_x': '+1 mm', 'min_y': '-2 mm', 'max_y': '+2 mm', 'sigma':10}
          

D = UniformLaserSpeckle(**params)

# %%
plt.imshow(D.Pxy);
# Out:
# /usr/share/miniconda/envs/distgen-dev/lib/python3.9/site-packages/matplotlib/cbook.py:733: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   x = np.array(x, subok=True, copy=copy)
